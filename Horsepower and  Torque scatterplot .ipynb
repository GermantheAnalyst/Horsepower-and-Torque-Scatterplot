# %% [markdown]
# # Torque and Speed Relationship: An Analogy

# %% [markdown]
#  ##### In an electric motor, the torque and speed relationship is defined by the formula: mechanical power equals the speed multiplied by the torque. The torque and speed relationship is inversely proportional since the rated output power of a motor is a fixed value. As output speed increases, the available output torque decreases proportionately. As the output torque increases, the output speed decreases proportionately. Although speed governs the maximum speed of an electric motor, having more torque enables the system to reach top speed in less time. The dynamic requirements for the intended application will determine whether it is better to have more torque or more speed. We can show with this scatterplot that the more speed, the more the torque is used in the car and it reduce the efficiency of the engine in the car.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import csv

# %%
with open("C:/Users/antho/OneDrive/Desktop/files/cars.csv", "r") as f:
    csv_reader = csv.DictReader(f)
    cars = list(csv_reader)

# %%
cars[0]
# Out:
# {'Height': '140',
#  'Length': '143',
#  'Width': '202',
#  'Engine Driveline': 'All-wheel drive',
#  'Engine Type': 'Audi 3.2L 6 cylinder 250hp 236ft-lbs',
#  'Engine Hybrid': 'True',
#  'Number of Forward Gears': '6',
#  'Engine Transmission': '6 Speed Automatic Select Shift',
#  'Fuel City mpg': '18',
#  'Fuel Type': 'Gasoline',
#  'Fuel Highway mpg': '25',
#  'Classification': 'Automatic transmission',
#  'ID': '2009 Audi A3 3.2',
#  'Make': 'Audi',
#  'Model Year': '2009 Audi A3',
#  'Year': '2009',
#  'Horsepower': '250',
#  'Torque': '236'}

# %%
horse_power = [int(car['Horsepower']) for car in cars]

# %%
torque_power = [int(car['Torque']) for car in cars]

# %%
mpg = [int(car['Fuel City mpg']) for car in cars]

# %%
horse_power[0]
# Out:
# 250

# %%
fig, ax = plt.subplots()
ax.scatter(horse_power, torque_power, alpha=.25, c=mpg)
ax.set_xlabel("Horse_power")
ax.set_ylabel("Torque_power")
# Out:
# Text(0, 0.5, 'Torque_power')
